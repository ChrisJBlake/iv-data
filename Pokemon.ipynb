# %%
import numpy as np
import pandas as pd

# %%
full = pd.read_csv("data/pokemon_full.csv")
full
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
full.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
small = full.loc[:, ~full.columns.str.startswith("against")].copy()
small
# Out:
#                        abilities  attack  base_egg_steps  base_happiness  \
# 0    ['Overgrow', 'Chlorophyll']      49            5120              70
# 1    ['Overgrow', 'Chlorophyll']      62            5120              70
# 2    ['Overgrow', 'Chlorophyll']     100            5120              70
# 3       ['Blaze', 'Solar Power']      52            5120              70
# 4       ['Blaze', 'Solar Power']      64            5120              70
# ..                           ...     ...             ...             ...
# 796              ['Beast Boost']     101           30720               0
# 797              ['Beast Boost']     181           30720               0
# 798              ['Beast Boost']     101           30720               0
# 799              ['Prism Armor']     107           30720               0
# 800               ['Soul-Heart']      95           30720               0
#
#      base_total capture_rate        classfication  defense  experience_growth  \
# ...

# %%
cols = "name type1 type2 hp attack defense sp_attack sp_defense speed base_total weight_kg capture_rate is_legendary".split()
small = full[cols].copy()
small
# Out:
#            name    type1   type2   hp  attack  defense  sp_attack  sp_defense  \
# 0     Bulbasaur    grass  poison   45      49       49         65          65
# 1       Ivysaur    grass  poison   60      62       63         80          80
# 2      Venusaur    grass  poison   80     100      123        122         120
# 3    Charmander     fire     NaN   39      52       43         60          50
# 4    Charmeleon     fire     NaN   58      64       58         80          65
# ..          ...      ...     ...  ...     ...      ...        ...         ...
# 796  Celesteela    steel  flying   97     101      103        107         101
# 797     Kartana    grass   steel   59     181      131         59          31
# 798    Guzzlord     dark  dragon  223     101       53         97          53
# 799    Necrozma  psychic     NaN   97     107      101        127          89
# 800    Magearna    steel   fairy   80      95      115        130         115
#
# ...

# %%
small[small.capture_rate != "30 (Meteorite)255 (Core)"].to_csv("data/pokemon_small.csv", index=False)

# %%
small = pd.read_csv("data/pokemon_small.csv")
small
# Out:
#            name    type1   type2   hp  attack  defense  sp_attack  sp_defense  \
# 0     Bulbasaur    grass  poison   45      49       49         65          65
# 1       Ivysaur    grass  poison   60      62       63         80          80
# 2      Venusaur    grass  poison   80     100      123        122         120
# 3    Charmander     fire     NaN   39      52       43         60          50
# 4    Charmeleon     fire     NaN   58      64       58         80          65
# ..          ...      ...     ...  ...     ...      ...        ...         ...
# 795  Celesteela    steel  flying   97     101      103        107         101
# 796     Kartana    grass   steel   59     181      131         59          31
# 797    Guzzlord     dark  dragon  223     101       53         97          53
# 798    Necrozma  psychic     NaN   97     107      101        127          89
# 799    Magearna    steel   fairy   80      95      115        130         115
#
# ...

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(small, train_size=.75)

# %%
def extract_

test_df.to_numpy()[:,9:13]
# Out:
# array([[280, 7.8, 235, 0],
#        [485, 24.9, 45, 0],
#        [435, 35.0, 45, 0],
#        [405, 29.0, 45, 0],
#        [468, 32.8, 155, 0],
#        [460, 100.0, 200, 0],
#        [450, 55.8, 75, 0],
#        [330, 7.0, 190, 0],
#        [424, 6.5, 45, 0],
#        [325, 6.5, 225, 0],
#        [474, 71.0, 60, 0],
#        [450, 34.6, 30, 0],
#        [310, 3.9, 190, 0],
#        [405, 22.5, 45, 0],
#        [330, 60.0, 180, 0],
#        [195, 3.2, 255, 0],
#        [285, 1.5, 190, 0],
#        [410, 56.0, 45, 0],
#        [525, 27.0, 45, 0],
#        [485, 34.5, 90, 0],
#        [330, 10.4, 190, 0],
#        [350, 20.0, 180, 0],
#        [551, 0.9, 120, 0],
#        [480, 16.3, 75, 0],
#        [237, 86.4, 180, 0],
#        [245, 1.5, 190, 0],
#        [485, 0.3, 60, 0],
#        [210, 3.2, 235, 0],
#        [495, 60.4, 45, 0],
#        [382, 16.0, 120, 0],
#        [510, 41.0, 60, 0],
#        [270, 5.5, 170, 0],
#        [600, 50.5, 3, 1],
#        [495, 33.5, 75, 0],
# ...
